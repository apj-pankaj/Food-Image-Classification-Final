# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -q streamlit

# %%
# !pip install -q streamlit pyngrok

# %%
# !nohup streamlit run /content/drive/MyDrive/Colab Notebooks/final_stream.py --server.port 8501 --server.headless true --server.enableCORS false > /content/streamlit.log 2>&1 &

# %%
# !nohup streamlit run '/content/drive/MyDrive/Colab Notebooks/final_stream.py' --server.port 8501 --server.headless true --server.enableCORS false > /content/streamlit.log 2>&1 &

# %%
from pyngrok import conf
conf.get_default().auth_token = "34roq2z9ZAvGRym2pVddsHyF9Ln_6KMQJiMPLz6hE83dH5oUU"
print("✅ ngrok authtoken configured!")
# Out:
# ✅ ngrok authtoken configured!

# %%
from pyngrok import ngrok, conf

# Optional: Use your auth token to avoid session limits
# conf.get_default().auth_token = "YOUR_NGROK_AUTH_TOKEN"

# Close old tunnels if any
for t in ngrok.get_tunnels():
    ngrok.disconnect(t.public_url)

public_url = ngrok.connect(addr="8501", proto="http")
print("🌍 Open your Streamlit app here:")
print(public_url.public_url)
# Out:
# WARNING:pyngrok.process.ngrok:t=2025-12-06T16:09:05+0000 lvl=warn msg="Stopping forwarder" name=http-8501-765ab597-248d-4e33-b2cb-8859dcead8c9 acceptErr="failed to accept connection: Listener closed"
# 🌍 Open your Streamlit app here:
# https://older-hypertragic-genia.ngrok-free.dev
